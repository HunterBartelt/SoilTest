# %%
from owslib.wcs import WebCoverageService
import rasterio as rs
from rasterio import plot

# %%
wcs = WebCoverageService('http://maps.isric.org/mapserv?map=/map/wrb.map')

# %%
cov_id = 'MostProbable'
mp = wcs.contents[cov_id]
mp.boundingboxes
# Out:
# [{'nativeSrs': 'http://www.opengis.net/def/crs/EPSG/0/4326',
#   'bbox': (-61.0674762500609, -180.0, 83.999167206, 186.933274624154)}]

# %%
mp.supportedFormats
# Out:
# ['image/tiff',
#  'image/png',
#  'image/jpeg',
#  'image/png; mode=8bit',
#  'image/vnd.jpeg-png',
#  'image/vnd.jpeg-png8']

# %%
subsets = [('X',-100, -75),('Y', 25, 50)]

# %%
crs = "http://www.opengis.net/def/crs/EPSG/0/152160"

# %%
response = wcs.getCoverage(
    identifier = [cov_id],
    crs = crs,
    subsets = subsets,
    resx = 250,
    resy = 250,
    format = mp.supportedFormats[2]
)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-11-abd489ef5858> in <module>
# ----> 1 response = wcs.getCoverage(
#       2     identifier = [cov_id],
#       3     crs = crs,
#       4     subsets = subsets,
#       5     resx = 250,
#
# /opt/conda/lib/python3.8/site-packages/owslib/coverage/wcs201.py in getCoverage(self, identifier, bbox, time, format, subsets, resolutions, sizes, crs, width, height, resx, resy, resz, parameter, method, timeout, **kwargs)
#     217         log.debug("WCS 2.0.1 DEBUG: Second part of URL: %s" % data)
#     218
# --> 219         u = openURL(base_url, data, method, self.cookies, auth=self.auth, timeout=timeout, headers=self.headers)
#     220         return u
#     221
#
# /opt/conda/lib/python3.8/site-packages/owslib/util.py in openURL(url_base, data, method, cookies, username, password, timeout, headers, verify, cert, auth)
#     212
#     213     if req.status_code in [404, 500, 502, 503, 504]:    # add more if needed
# --> 214         req.raise_for_status()
#     215
#     216     # check for service exceptions without the http header set
#
# /opt/conda/lib/python3.8/site-packages/requests/models.py in raise_for_status(self)
#     941
#     942         if http_error_msg:
# --> 943             raise HTTPError(http_error_msg, response=self)
#     944
#     945     def close(self):
#
# HTTPError: 500 Server Error: Internal Server Error for url: https://maps.isric.org/mapserv?map=/map/wrb.map&amp;&version=2.0.1&request=GetCoverage&service=WCS&CoverageID=MostProbable&crs=http://www.opengis.net/def/crs/EPSG/0/152160&format=image/jpeg&subset=X(-100,-75)&subset=Y(25,50)

# %%
with open ('./MostProbableWest.jpg','wb') as file:
    file.write(response.read())

# %%
response = wcs.getCoverage(
    identifier = [cov_id],
    crs = crs,
    subsets = subsets,
    resx = 250,
    resy = 250,
    format = mp.supportedFormats[0]
)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-12-6e4beddaf3a4> in <module>
# ----> 1 response = wcs.getCoverage(
#       2     identifier = [cov_id],
#       3     crs = crs,
#       4     subsets = subsets,
#       5     resx = 250,
#
# /opt/conda/lib/python3.8/site-packages/owslib/coverage/wcs201.py in getCoverage(self, identifier, bbox, time, format, subsets, resolutions, sizes, crs, width, height, resx, resy, resz, parameter, method, timeout, **kwargs)
#     217         log.debug("WCS 2.0.1 DEBUG: Second part of URL: %s" % data)
#     218
# --> 219         u = openURL(base_url, data, method, self.cookies, auth=self.auth, timeout=timeout, headers=self.headers)
#     220         return u
#     221
#
# /opt/conda/lib/python3.8/site-packages/owslib/util.py in openURL(url_base, data, method, cookies, username, password, timeout, headers, verify, cert, auth)
#     212
#     213     if req.status_code in [404, 500, 502, 503, 504]:    # add more if needed
# --> 214         req.raise_for_status()
#     215
#     216     # check for service exceptions without the http header set
#
# /opt/conda/lib/python3.8/site-packages/requests/models.py in raise_for_status(self)
#     941
#     942         if http_error_msg:
# --> 943             raise HTTPError(http_error_msg, response=self)
#     944
#     945     def close(self):
#
# HTTPError: 500 Server Error: Internal Server Error for url: https://maps.isric.org/mapserv?map=/map/wrb.map&amp;&version=2.0.1&request=GetCoverage&service=WCS&CoverageID=MostProbable&crs=http://www.opengis.net/def/crs/EPSG/0/152160&format=image/tiff&subset=X(-100,-75)&subset=Y(25,50)

# %%
with open ('./MostProbableWest.tif','wb') as file:
    file.write(response.read())

# %%
MostProb = rs.open('./MostProbableWest.tif',driver = "GTiff")
# %matplotlib inline
rs.plot.show(MostProb, title = "Most Probable Soil Type", cmap= "gist_ncar")
# Out:
# <AxesSubplot:title={'center':'Most Probable Soil Type'}>
